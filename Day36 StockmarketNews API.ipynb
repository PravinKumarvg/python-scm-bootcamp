# %%
#calling Stock market API and finding the values for TESLA stock

import requests

Stockmarket = "https://www.alphavantage.co/query?"
API = "GVBISBJR138XM4F3."

Stockparams = {
    "function":"TIME_SERIES_INTRADAY",
     "symbol": "TSLA",
     "interval": "5min",
    "apikey": API
}

request = requests.get(Stockmarket, params = Stockparams )
request.raise_for_status()
data = request.json()
print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'TSLA', '3. Last Refreshed': '2025-10-14 19:55:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2025-10-14 19:55:00': {'1. open': '429.1500', '2. high': '429.2200', '3. low': '428.9200', '4. close': '428.9700', '5. volume': '21291'}, '2025-10-14 19:50:00': {'1. open': '429.2400', '2. high': '429.2600', '3. low': '429.0200', '4. close': '429.1200', '5. volume': '6093'}, '2025-10-14 19:45:00': {'1. open': '428.8500', '2. high': '429.2500', '3. low': '428.8500', '4. close': '429.2484', '5. volume': '7406'}, '2025-10-14 19:40:00': {'1. open': '429.1600', '2. high': '429.2600', '3. low': '428.8000', '4. close': '428.8800', '5. volume': '9264'}, '2025-10-14 19:35:00': {'1. open': '429.2700', '2. high': '429.4500', '3. low': '429.1100', '4. close': '429.2100', '5. volume': '5257'}, '2025-10-14 19:30:00': {'1. open': '429.370
# ...

# %%
#Calling stock market API calculating the percent difference between today and yesterday and calling news PAI is the difference is greater than 5.

import requests

Stockmarket = "https://www.alphavantage.co/query?"
API = "GVBISBJR138XM4F3."

NewsEndpoint = "https://newsapi.org/v2/everything"
NewsAPI = "0ce475d1c59c4582b68ac36f887d2f17"

Stockparams = {
    "function":"TIME_SERIES_DAILY",
     "symbol": "TSLA",
    "apikey": API
}

request = requests.get(Stockmarket, params = Stockparams )
request.raise_for_status()
data = request.json()
print(data)

timeseries = data.get("Time Series (Daily)", {})

# Loop through each timestamp and print the closing price
for timestamp, values in timeseries.items():
    closeprice = values["4. close"] # Correct key with space
    print(f"{timestamp} → Close: {closeprice}")
    sorted_dates = sorted(timeseries.keys(), reverse = True)
    today_close = float(timeseries[sorted_dates[0]]["4. close"])
    yesterday_close = float(timeseries[sorted_dates[1]]["4. close"])
    differencePrice = today_close - yesterday_close
    percent_change = (differencePrice/yesterday_close)*100

    print(f"The difference between yesterday and today price is {differencePrice}")
    print(f"Percentage Change: {percent_change:.2f}%")


    if percent_change > 5:
        newsparams = {
            "apiKey":NewsAPI,
            "qInTitle":"TSLA",
        }
        newsresponse = requests.get(NewsEndpoint, params = newparams)
        newsdata = newsresponse.json()["article"]
        print(newsdata)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'TSLA', '3. Last Refreshed': '2025-10-14', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-10-14': {'1. open': '426.7900', '2. high': '434.2000', '3. low': '417.8600', '4. close': '429.2400', '5. volume': '72669438'}, '2025-10-13': {'1. open': '423.5300', '2. high': '436.8900', '3. low': '419.7000', '4. close': '435.9000', '5. volume': '79552785'}, '2025-10-10': {'1. open': '436.5400', '2. high': '443.1300', '3. low': '411.4500', '4. close': '413.4900', '5. volume': '112107870'}, '2025-10-09': {'1. open': '431.8100', '2. high': '436.3500', '3. low': '426.1800', '4. close': '435.5400', '5. volume': '69339928'}, '2025-10-08': {'1. open': '437.5700', '2. high': '441.3300', '3. low': '425.2300', '4. close': '438.6900', '5. volume': '71192128'}, '2025-10-07': {'1. open': '447.8200', '2. high': '452.6800', '3. low': '432.4501', '4. close': '433.0900',
# ...
